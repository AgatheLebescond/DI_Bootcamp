# %% [markdown]
# Exercise 1: Basic Usage of SciPy
# Task: Import the SciPy library and explore its version.

# %%
import scipy

# Display the version of SciPy
print("Version de SciPy :", scipy.__version__)
# Out:
# Version de SciPy : 1.13.1

# %% [markdown]
# Exercise 2: Descriptive Statistics
# Task: Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample Dataset:
# data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
from scipy import stats
import numpy as np

# Sample dataset
data = [12, 15, 13, 12, 18, 20, 22, 21]

# Calculate descriptive statistics
mean = np.mean(data)
median = np.median(data)
variance = stats.tvar(data)
std_dev = stats.tstd(data)

# Display the results
print("Mean:", mean)
print("Median:", median)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 16.625
# Median: 16.5
# Variance: 17.125
# Standard Deviation: 4.138236339311712

# %% [markdown]
# Exercise 3: Understanding Distributions
# Task: Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.
# Code Example:
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import norm

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean, std_dev = 50, 10

# Generate a range of x values
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

# Calculate the corresponding y values for the normal distribution
y = norm.pdf(x, mean, std_dev)

# Plot the distribution
plt.figure(figsize=(10, 6))
plt.plot(x, y, label=f'Normal Distribution (μ={mean}, σ={std_dev})', color='blue')
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.axvline(x=mean, color='red', linestyle='--', label='Mean')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Exercise 4: T-Test Application
# Task: Perform a T-test on two sets of randomly generated data.
# Code Example:
# data1 = np.random.normal(50, 10, 100)
# data2 = np.random.normal(60, 10, 100)

# %%
import numpy as np
from scipy import stats

# Generate two sets of random data
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 10, 100)

# Perform a T-test
statistic, p_value = stats.ttest_ind(data1, data2)

# Display the results
print("T-Statistic:", statistic)
print("P-Value:", p_value)
# Out:
# T-Statistic: -7.169023151641589
# P-Value: 1.4656435983689548e-11

# %% [markdown]
# Exercise 5: Linear Regression Analysis
# Objective: Apply linear regression to a dataset and interpret the results.
# Task: Given a dataset of housing prices (house_prices) and their corresponding sizes (house_sizes), use linear regression to predict the price of a house given its size.
# Dataset:
# house_sizes: [50, 70, 80, 100, 120] (in square meters)
# house_prices: [150,000, 200,000, 210,000, 250,000, 280,000] (in currency units)
# Questions:
# What is the slope and intercept of the regression line?
# Predict the price of a house that is 90 square meters.
# Interpret the meaning of the slope in the context of housing prices.

# %%
from scipy.stats import linregress
import numpy as np

# Ensemble de données
house_sizes = np.array([50, 70, 80, 100, 120])  # en mètres carrés
house_prices = np.array([150000, 200000, 210000, 250000, 280000])  # en unités monétaires

# Effectuer une régression linéaire
slope, intercept, r_value, p_value, std_err = linregress(house_sizes, house_prices)

# Prédire le prix d'une maison de 90 mètres carrés
predicted_price_90_sqm = slope * 90 + intercept

# Afficher les résultats
print("Pente de la ligne de régression :", slope)
print("Ordonnée à l'origine de la ligne de régression :", intercept)
print("Prix prédit pour une maison de 90 mètres carrés :", predicted_price_90_sqm)
# Out:
# Pente de la ligne de régression : 1828.7671232876712
# Ordonnée à l'origine de la ligne de régression : 64383.56164383562
# Prix prédit pour une maison de 90 mètres carrés : 228972.60273972602

# %% [markdown]
# La pente de la ligne de régression représente le changement moyen du prix de la maison pour chaque augmentation d'un mètre carré de sa taille. Par exemple, si la pente est de 2000, cela signifie que pour chaque mètre carré supplémentaire, le prix de la maison augmente en moyenne de 2000 unités monétaires.

# %% [markdown]
# Exercise 6: Understanding ANOVA
# Objective: Test understanding of ANOVA and its application.
# Task: Three different fertilizers are applied to three separate groups of plants to test their effectiveness. The growth in centimeters is recorded.
# Dataset:
# fertilizer_1: [5, 6, 7, 6, 5]
# fertilizer_2: [7, 8, 7, 9, 8]
# fertilizer_3: [4, 5, 4, 3, 4]
# Questions:
# Perform an ANOVA test on the given data. What are the F-value and P-value?
# Based on the P-value, do the fertilizers have significantly different effects on plant growth?
# Explain what would happen if the P-value were greater than 0.05.

# %%
import scipy.stats as stats

# Dataset
fertilizer_1 = [5, 6, 7, 6, 5]
fertilizer_2 = [7, 8, 7, 9, 8]
fertilizer_3 = [4, 5, 4, 3, 4]

# Perform one-way ANOVA test
f_value, p_value = stats.f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)

# Output the results
print("F-value:", f_value)
print("P-value:", p_value)

# Interpretation based on P-value
if p_value < 0.05:
    print("The fertilizers have significantly different effects on plant growth.")
else:
    print("There is no significant difference in the effects of the fertilizers on plant growth.")

# Explanation for P-value greater than 0.05
# Out:
# F-value: 28.52631578947368
# P-value: 2.7542672098048448e-05
# The fertilizers have significantly different effects on plant growth.

# %% [markdown]
# Exercise 7: Probability Distributions (Optional)
# Work with a binomial distribution: calculate probabilities for different numbers of successes.
# Example: Calculating the probability of getting exactly 5 heads in 10 coin flips.

# %%
import math

# Définir les paramètres
n = 10  # nombre total de lancers
k = 5   # nombre de succès (piles)
p = 0.5 # probabilité de succès (pile)

# Calculer la probabilité binomiale
probabilite = math.comb(n, k) * (p ** k) * ((1 - p) ** (n - k))
print("La probabilité est :", probabilite)
# Out:
# La probabilité est : 0.24609375

# %% [markdown]
# Exercice 8 : Calcul des coefficients de corrélation
#
# Nous allons calculer les coefficients de corrélation de Pearson et de Spearman pour un DataFrame contenant des données sur l'âge et le revenu.

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr

# Créer un DataFrame avec les données
data = pd.DataFrame({
    'age': [23, 25, 30, 35, 40],
    'income': [35000, 40000, 50000, 60000, 70000]
})

# Calculer le coefficient de corrélation de Pearson
pearson_corr, pearson_p_value = pearsonr(data['age'], data['income'])

# Calculer le coefficient de corrélation de Spearman
spearman_corr, spearman_p_value = spearmanr(data['age'], data['income'])

pearson_corr, spearman_corr
# Out:
# (np.float64(0.9996907452347202), np.float64(0.9999999999999999))
